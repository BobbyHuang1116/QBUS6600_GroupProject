# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import StandardScaler

# %%
sales_train = pd.read_csv('BigW_data/Sales by customer location train.csv')
sales_test = pd.read_csv('BigW_data/Sales by customer location test.csv')
combined_df = pd.concat([sales_train, sales_test], ignore_index=True)

store = pd.read_csv('BigW_data/Sales by store location.csv')
media = pd.read_csv('BigW_data/Media Investment.csv')
# aus = gpd.read_file('SA4_2021_AUST_SHP_GDA2020/SA4_2021_AUST_GDA2020.shp')

# %% [markdown]
# ### Data Cleaning

# %%
sales_train.isnull().sum()
# Out:
# store_id                             0
# sales_channel                        0
# customer_state                       0
# customer_postcode                    7
# price_lifestage_segment          13565
# customer_count                       0
# transaction_count                    0
# total_sale_value                     0
# total_sale_value_ex_gst              0
# total_promotional_sales_value        0
# financial_week_end_date              0
# dtype: int64

# %%
sales_test.isnull().sum()
# Out:
# store_id                            0
# sales_channel                       0
# customer_state                      0
# customer_postcode                   1
# price_lifestage_segment          2645
# customer_count                      0
# transaction_count                   0
# total_sale_value                    0
# total_sale_value_ex_gst             0
# total_promotional_sales_value       0
# financial_week_end_date             0
# dtype: int64

# %%
sales_train1 = sales_train.dropna()
sales_train1 = sales_train1.reset_index(drop=True)

sales_test1 = sales_test.dropna()
sales_test1 = sales_test1.reset_index(drop=True)

combined_df1 = combined_df.dropna()
combined_df1 = combined_df.reset_index(drop=True)

# %%
# turn negative values in promotion sales to 0 
sales_train1.loc[sales_train1['total_promotional_sales_value'] < 0, 'total_promotional_sales_value']=0
sales_test1.loc[sales_test1['total_promotional_sales_value'] < 0, 'total_promotional_sales_value']=0
combined_df.loc[combined_df['total_promotional_sales_value'] < 0, 'total_promotional_sales_value']=0

# %%
sales_train1.isnull().sum()
# Out:
# store_id                         0
# sales_channel                    0
# customer_state                   0
# customer_postcode                0
# price_lifestage_segment          0
# customer_count                   0
# transaction_count                0
# total_sale_value                 0
# total_sale_value_ex_gst          0
# total_promotional_sales_value    0
# financial_week_end_date          0
# dtype: int64

# %%
store1 = store.copy()
store1['co_location_flag'] = store1['co_location_flag'].fillna(True)
store1.iloc[0,7] = '>5 KM'
store1.iloc[0,8] = '>5 KM'

# %%
store1.isnull().sum()
# Out:
# store_id                         0
# store_state                      0
# store_postcode                   0
# store_latitude                   0
# store_longitude                  0
# co_location_flag                 0
# sales_channel                    0
# distance_to_kmart                0
# distance_to_target               0
# total_sale_value                 0
# total_sale_value_ex_gst          0
# total_promotional_sales_value    0
# dtype: int64

# %%
media.head()
# Out:
#   week_ending state  media_amount_spend
# 0  11/07/2021    NT         5960.266526
# 1   9/10/2022    NT        11727.146180
# 2  22/01/2023    NT        13918.705420
# 3   2/01/2022    NT        13076.182500
# 4   5/06/2022    NT        20148.750420

# %%
media['state'].unique()
# Out:
# array(['NT', 'SA', 'WA', 'ACT', 'NSW', 'QLD', 'TAS', 'VIC', 'UNKNOWN',
#        'National'], dtype=object)

# %%
media[(media['state']=='UNKNOWN')| (media['state']=='National')]
# Out:
#     week_ending     state  media_amount_spend
# 824  20/03/2022   UNKNOWN        9.400030e-01
# 825  18/07/2021   UNKNOWN        2.900000e-01
# 826   6/11/2022   UNKNOWN        1.637001e+01
# 827  12/02/2023   UNKNOWN        3.100855e+01
# 828  26/02/2023   UNKNOWN        3.354000e+01
# ..          ...       ...                 ...
# 943   1/01/2023  National        9.323000e+06
# 944   4/07/2021  National        4.810000e+06
# 945   3/10/2021  National        9.185000e+06
# 946   5/12/2021  National        6.429000e+06
# 947   6/11/2022  National        1.840900e+07
#
# [124 rows x 3 columns]

# %%
media1 = media[(media['state']!='UNKNOWN')& (media['state']!='National')]

# %%
media1[(media1['state']=='UNKNOWN')& (media1['state']=='National')]
# Out:
# Empty DataFrame
# Columns: [week_ending, state, media_amount_spend]
# Index: []

# %%
media1[media1['media_amount_spend']<0]
# Out:
# Empty DataFrame
# Columns: [week_ending, state, media_amount_spend]
# Index: []

# %%
media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# media1['week_ending'] = media1['week_ending'].dt.strftime('%Y-%m-%d')
# Out:
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '22/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '26/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '13/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '16/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '15/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '24/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '28/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '31/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '26/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '14/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '17/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '18/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '25/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '28/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '30/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '19/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '27/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '20/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '22/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '15/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '23/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '19/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '22/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '19/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '18/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '28/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '18/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '17/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '31/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '21/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '29/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '16/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '20/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '29/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '27/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '27/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '25/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '20/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '20/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '18/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '29/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '17/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '21/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '13/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '14/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '26/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '26/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '19/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '25/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '30/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '24/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '23/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '23/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '24/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '27/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '13/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '15/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '16/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '21/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '13/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '25/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: UserWarning: Parsing '30/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/4248562551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   media1['week_ending'] = pd.to_datetime(media1['week_ending'])

# %%
media1['week_ending'].min()
# Out:
# Timestamp('2021-01-08 00:00:00')

# %%
media1['week_ending'].max()
# Out:
# Timestamp('2023-12-02 00:00:00')

# %%
media1['year_month'] = media1['week_ending'].dt.strftime('%Y-%m')
# Out:
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_73073/2003241533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   media1['year_month'] = media1['week_ending'].dt.strftime('%Y-%m')

# %% [markdown]
# ### (Media) Group by year_month

# %%
media1 = media1.sort_values(by='week_ending').reset_index(drop=True)
media1['week_ending'].unique()
# media_monthly['year_month'] = media_monthly['year_month'].dt.strftime('%Y-%m')
# Out:
# array(['2021-01-08T00:00:00.000000000', '2021-02-05T00:00:00.000000000',
#        '2021-03-10T00:00:00.000000000', '2021-03-21T00:00:00.000000000',
#        '2021-03-28T00:00:00.000000000', '2021-04-04T00:00:00.000000000',
#        '2021-04-07T00:00:00.000000000', '2021-04-18T00:00:00.000000000',
#        '2021-04-25T00:00:00.000000000', '2021-05-09T00:00:00.000000000',
#        '2021-05-12T00:00:00.000000000', '2021-05-16T00:00:00.000000000',
#        '2021-05-23T00:00:00.000000000', '2021-05-30T00:00:00.000000000',
#        '2021-06-06T00:00:00.000000000', '2021-06-13T00:00:00.000000000',
#        '2021-06-20T00:00:00.000000000', '2021-06-27T00:00:00.000000000',
#        '2021-07-11T00:00:00.000000000', '2021-07-18T00:00:00.000000000',
#        '2021-07-25T00:00:00.000000000', '2021-08-08T00:00:00.000000000',
#        '2021-08-15T00:00:00.000000000', '2021-08-22T00:00:00.000000000',
#        '2021-08-29T00:00:00.000000000', '2021-09-05T00:00:00.000000000',
#        '2021-09-19T00:00:00.000000000', '2021-09-26T00:00:00.000000000',
#        '2021-10-10T00:00:00.000000000', '2021-10-17T00:00:00.000000000',
#        '2021-10-24T00:00:00.000000000', '2021-10-31T00:00:00.000000000',
#        '2021-11-04T00:00:00.000000000', '2021-11-07T00:00:00.000000000',
#        '2021-11-14T00:00:00.000000000', '2021-11-21T00:00:00.000000000',
#        '2021-11-28T00:00:00.000000000', '2021-12-09T00:00:00.000000000',
#        '2021-12-12T00:00:00.000000000', '2021-12-19T00:00:00.000000000',
#        '2021-12-26T00:00:00.000000000', '2022-01-05T00:00:00.000000000',
#        '2022-01-16T00:00:00.000000000', '2022-01-23T00:00:00.000000000',
#        '2022-01-30T00:00:00.000000000', '2022-02-01T00:00:00.000000000',
#        '2022-02-10T00:00:00.000000000', '2022-02-13T00:00:00.000000000',
#        '2022-02-20T00:00:00.000000000', '2022-02-27T00:00:00.000000000',
#        '2022-03-04T00:00:00.000000000', '2022-03-07T00:00:00.000000000',
#        '2022-03-13T00:00:00.000000000', '2022-03-20T00:00:00.000000000',
#        '2022-03-27T00:00:00.000000000', '2022-04-09T00:00:00.000000000',
#        '2022-04-12T00:00:00.000000000', '2022-04-17T00:00:00.000000000',
#        '2022-04-24T00:00:00.000000000', '2022-05-06T00:00:00.000000000',
#        '2022-05-15T00:00:00.000000000', '2022-05-22T00:00:00.000000000',
#        '2022-05-29T00:00:00.000000000', '2022-06-02T00:00:00.000000000',
#        '2022-06-03T00:00:00.000000000', '2022-06-11T00:00:00.000000000',
#        '2022-06-19T00:00:00.000000000', '2022-06-26T00:00:00.000000000',
#        '2022-07-08T00:00:00.000000000', '2022-07-17T00:00:00.000000000',
#        '2022-07-24T00:00:00.000000000', '2022-07-31T00:00:00.000000000',
#        '2022-08-05T00:00:00.000000000', '2022-08-14T00:00:00.000000000',
#        '2022-08-21T00:00:00.000000000', '2022-08-28T00:00:00.000000000',
#        '2022-09-01T00:00:00.000000000', '2022-09-10T00:00:00.000000000',
#        '2022-09-18T00:00:00.000000000', '2022-09-25T00:00:00.000000000',
#        '2022-10-04T00:00:00.000000000', '2022-10-07T00:00:00.000000000',
#        '2022-10-16T00:00:00.000000000', '2022-10-23T00:00:00.000000000',
#        '2022-10-30T00:00:00.000000000', '2022-11-09T00:00:00.000000000',
#        '2022-11-12T00:00:00.000000000', '2022-11-13T00:00:00.000000000',
#        '2022-11-20T00:00:00.000000000', '2022-11-27T00:00:00.000000000',
#        '2022-12-06T00:00:00.000000000', '2022-12-18T00:00:00.000000000',
#        '2022-12-25T00:00:00.000000000', '2023-01-01T00:00:00.000000000',
#        '2023-01-15T00:00:00.000000000', '2023-01-22T00:00:00.000000000',
#        '2023-01-29T00:00:00.000000000', '2023-02-19T00:00:00.000000000',
#        '2023-02-26T00:00:00.000000000', '2023-05-02T00:00:00.000000000',
#        '2023-05-03T00:00:00.000000000', '2023-08-01T00:00:00.000000000',
#        '2023-12-02T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# groupby data instead of state beecause all states has same media amount spend trend throughout each year, 
# although their spend amount is different

media_monthly = pd.DataFrame(media1.groupby(['year_month','state'])['media_amount_spend'].sum().round(2)).reset_index()


media_monthly
# Out:
#     year_month state  media_amount_spend
# 0      2021-01   ACT             5453.21
# 1      2021-01   NSW          2950173.44
# 2      2021-01    NT             6038.13
# 3      2021-01   QLD          1516658.56
# 4      2021-01    SA           397344.54
# ..         ...   ...                 ...
# 227    2023-12   QLD           219962.82
# 228    2023-12    SA            74718.79
# 229    2023-12   TAS            13638.74
# 230    2023-12   VIC           257337.27
# 231    2023-12    WA           135788.38
#
# [232 rows x 3 columns]

# %%
# mean media spend amount 2021-03 and 2022-03
filtered_df = media_monthly[media_monthly['year_month'].isin(['2021-03', '2022-03'])]
march_2023 = filtered_df.groupby(['state'])['media_amount_spend'].mean()
print(march_2023)

# mean media spend amount 2021-04 and 2022-04
filtered_df1 = media_monthly[media_monthly['year_month'].isin(['2021-04', '2022-04'])]
april_2023 = filtered_df1.groupby(['state'])['media_amount_spend'].mean()
print(april_2023)
# Out:
# state
# ACT      31867.980
# NSW    6180823.875
# NT       49288.670
# QLD    2876333.925
# SA      754912.965
# TAS      73217.425
# VIC    4200653.960
# WA     1318948.455
# Name: media_amount_spend, dtype: float64
# state
# ACT      29061.305
# NSW    7483414.290
# NT       46737.520
# QLD    3584293.675
# SA      889427.310
# TAS      91642.150
# VIC    5631157.240
# WA     1502191.465
# Name: media_amount_spend, dtype: float64

# %%
# missing values from 2023-03 and 04 media spend have been filled with mean values from 2021/2022-03 and 04
# each state has it's own media spend amount each month of year 

m_2023 = {'year_month':'2023-03',
          'state':['ACT','NSW','NT','QLD','SA','TAS','VIC','WA'],
          'media_amount_spend':[31867.980, 6180823.875, 49288.670, 2876333.925, 754912.965, 73217.425, 4200653.960,1318948.455]}

a_2023 = {'year_month':'2023-04',
          'state':['ACT','NSW','NT','QLD','SA','TAS','VIC','WA'],
          'media_amount_spend':[29061.305, 7483414.290, 46737.520, 3584293.675, 889427.310, 91642.150, 5631157.240,1502191.465]}



m_2023 = pd.DataFrame(m_2023)
a_2023 = pd.DataFrame(a_2023)

# append missing values to dataframe
media_monthly = pd.concat([media_monthly, m_2023, a_2023], ignore_index=True)

# %%
media_monthly
# Out:
#     year_month state  media_amount_spend
# 0      2021-01   ACT            5453.210
# 1      2021-01   NSW         2950173.440
# 2      2021-01    NT            6038.130
# 3      2021-01   QLD         1516658.560
# 4      2021-01    SA          397344.540
# ..         ...   ...                 ...
# 243    2023-04   QLD         3584293.675
# 244    2023-04    SA          889427.310
# 245    2023-04   TAS           91642.150
# 246    2023-04   VIC         5631157.240
# 247    2023-04    WA         1502191.465
#
# [248 rows x 3 columns]

# %%
media_monthly['year_month'] = pd.to_datetime(media_monthly['year_month'], format='%Y-%m')
media_monthly['year_month'] = media_monthly['year_month'].dt.strftime('%Y-%m')

media_monthly
# Out:
#     year_month state  media_amount_spend
# 0      2021-01   ACT            5453.210
# 1      2021-01   NSW         2950173.440
# 2      2021-01    NT            6038.130
# 3      2021-01   QLD         1516658.560
# 4      2021-01    SA          397344.540
# ..         ...   ...                 ...
# 243    2023-04   QLD         3584293.675
# 244    2023-04    SA          889427.310
# 245    2023-04   TAS           91642.150
# 246    2023-04   VIC         5631157.240
# 247    2023-04    WA         1502191.465
#
# [248 rows x 3 columns]

# %%
media_monthly = media_monthly.sort_values(by='year_month').reset_index(drop=True)

# drop 2023-08, 2023-12
# media_monthly = media_monthly.drop([29, 30]).reset_index(drop=True)
media_monthly
# Out:
#     year_month state  media_amount_spend
# 0      2021-01   ACT             5453.21
# 1      2021-01   NSW          2950173.44
# 2      2021-01    NT             6038.13
# 3      2021-01   QLD          1516658.56
# 4      2021-01    SA           397344.54
# ..         ...   ...                 ...
# 243    2023-12    SA            74718.79
# 244    2023-12   QLD           219962.82
# 245    2023-12    NT            13379.36
# 246    2023-12   NSW           433767.00
# 247    2023-12   ACT             9091.72
#
# [248 rows x 3 columns]

# %%
media_monthly.rename(columns={'state': 'customer_state'}, inplace=True)
media_monthly
# Out:
#     year_month customer_state  media_amount_spend
# 0      2021-01            ACT             5453.21
# 1      2021-01            NSW          2950173.44
# 2      2021-01             NT             6038.13
# 3      2021-01            QLD          1516658.56
# 4      2021-01             SA           397344.54
# ..         ...            ...                 ...
# 243    2023-12             SA            74718.79
# 244    2023-12            QLD           219962.82
# 245    2023-12             NT            13379.36
# 246    2023-12            NSW           433767.00
# 247    2023-12            ACT             9091.72
#
# [248 rows x 3 columns]

# %% [markdown]
# ### Combine Customer Location & Store

# %%
sales_train1['price_lifestage_segment'] = sales_train1['price_lifestage_segment'].astype(str)
combined_df1['price_lifestage_segment'] = combined_df1['price_lifestage_segment'].astype(str)

# %%
sales_train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1814020 entries, 0 to 1814019
# Data columns (total 11 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   store_id                       object
#  1   sales_channel                  object
#  2   customer_state                 object
#  3   customer_postcode              float64
#  4   price_lifestage_segment        object
#  5   customer_count                 int64
#  6   transaction_count              int64
#  7   total_sale_value               float64
#  8   total_sale_value_ex_gst        float64
#  9   total_promotional_sales_value  float64
#  10  financial_week_end_date        object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 152.2+ MB

# %%
store_ids_set1 = set(sales_train1['store_id'])
store_ids_set2 = set(store1['store_id'])

# Find unmatched store IDs
unmatched_ids_df1 = store_ids_set1 - store_ids_set2
unmatched_ids_df2 = store_ids_set2 - store_ids_set1

# Display unmatched store IDs
print("Unmatched Store IDs in DataFrame 1:", unmatched_ids_df1)
print("Unmatched Store IDs in DataFrame 2:", unmatched_ids_df2)
# Out:
# Unmatched Store IDs in DataFrame 1: set()
# Unmatched Store IDs in DataFrame 2: {'f639b3bffb0910cb1de42fee016df58d'}

# %%
# sales train drop nan 后比store dataset 少一个store id, 所以把这个store id 从store中删除了

store1 = store1[store1['store_id'] != 'f639b3bffb0910cb1de42fee016df58d']

# %%
# Store dataset group by store id

unique_store = store1.groupby(['store_id']).agg({
    'store_state':'first','store_postcode':'first', 'store_latitude':'first' ,'store_longitude':'first', 
       'co_location_flag':'first', 'distance_to_kmart':'first', 'distance_to_target':'first',
    'total_sale_value': 'sum','total_promotional_sales_value':'sum','total_sale_value_ex_gst':'sum'
}).reset_index()

unique_store
# Out:
#                              store_id store_state  store_postcode  \
# 0    00f80c0962fb37ea8fb72accc75546c8         TAS            7050
# 1    00fdea78e677259a3e44868468f24bbf         QLD            4053
# 2    03d9b714d7ac602a9755a662c1d65be4         QLD            4187
# 3    059fffb74fa5f6ebe37bd1df479c02f7         QLD            4720
# 4    05c3e372f03989d8e904372a2767f158          SA            5158
# ..                                ...         ...             ...
# 172  fbfaede8d00839631393db8bdecbb3db          SA            5046
# 173  fc25b8de93fc78247ad51123fd96c07d          SA            5125
# 174  fc2751520dda99c0c7f267904fb483e7         NSW            2594
# 175  fec8038ae4436caa7188b2e3f0bd216f          WA            6155
# 176  fee67cadcc3a0bec8e00641884903c45         NSW            2575
#
#      store_latitude  store_longitude  co_location_flag distance_to_kmart  \
# 0          -42.9759         147.3085              True             >5 KM
# 1          -27.4093         152.9800              True            1-3 KM
# 2          -19.3174         146.7285              True            3-5 KM
# 3          -23.5169         148.2108              True             >5 KM
# 4          -35.0787         138.5169              True             >5 KM
# ..              ...              ...               ...               ...
# 172        -35.0138         138.5447              True       Same Centre
# 173        -34.7753         138.7160              True            3-5 KM
# 174        -34.3036         148.2702             False             >5 KM
# 175        -32.0388         115.8889              True            3-5 KM
# 176        -34.4472         150.4382              True             >5 KM
#
#     distance_to_target  total_sale_value  total_promotional_sales_value  \
# 0                >5 KM       63516938.31                     7741346.78
# 1          Same Centre       52957737.59                     7563628.70
# 2                >5 KM       76112737.87                     7932218.02
# 3                >5 KM       55341416.14                     6735050.98
# 4               3-5 KM       30462616.26                     5037218.08
# ..                 ...               ...                            ...
# 172        Same Centre       73475153.85                     9017465.16
# 173             3-5 KM       42522051.91                     6505523.65
# 174              >5 KM       42959298.99                     5465555.31
# 175             3-5 KM       51649026.67                     6971991.23
# 176              >5 KM       52925234.57                     7064539.34
#
#      total_sale_value_ex_gst
# 0                57946972.60
# 1                48297404.90
# 2                69489762.91
# 3                50473985.98
# 4                27829177.50
# ..                       ...
# 172              67049965.38
# 173              38834898.46
# 174              39231426.97
# 175              47150907.22
# 176              48278611.48
#
# [177 rows x 11 columns]

# %%
# merge training set and unique store dataset 

sales_train1 = sales_train1.merge(unique_store, on='store_id', how='left')
sales_train1

sales_test1 = sales_test1.merge(unique_store, on='store_id', how='left')
sales_test1

combined_df1 = combined_df1.merge(unique_store, on='store_id', how='left')

# %% [markdown]
# ### Combine Slaes_train1 & media_monthly

# %%
sales_train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1814020 entries, 0 to 1814019
# Data columns (total 21 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   store_id                         object
#  1   sales_channel                    object
#  2   customer_state                   object
#  3   customer_postcode                float64
#  4   price_lifestage_segment          object
#  5   customer_count                   int64
#  6   transaction_count                int64
#  7   total_sale_value_x               float64
#  8   total_sale_value_ex_gst_x        float64
#  9   total_promotional_sales_value_x  float64
#  10  financial_week_end_date          object
#  11  store_state                      object
#  12  store_postcode                   int64
#  13  store_latitude                   float64
#  14  store_longitude                  float64
#  15  co_location_flag                 bool
#  16  distance_to_kmart                object
#  17  distance_to_target               object
#  18  total_sale_value_y               float64
#  19  total_promotional_sales_value_y  float64
#  20  total_sale_value_ex_gst_y        float64
# dtypes: bool(1), float64(9), int64(3), object(8)
# memory usage: 292.4+ MB

# %%
sales_train1['financial_week_end_date'] =pd.to_datetime(sales_train1['financial_week_end_date'])
sales_test1['financial_week_end_date'] =pd.to_datetime(sales_test1['financial_week_end_date'])
combined_df1['financial_week_end_date'] =pd.to_datetime(combined_df1['financial_week_end_date'])

# %%
sales_train1['year_month'] = sales_train1['financial_week_end_date'].dt.strftime('%Y-%m')
sales_test1['year_month'] = sales_test1['financial_week_end_date'].dt.strftime('%Y-%m')
combined_df1['year_month'] = combined_df1['financial_week_end_date'].dt.strftime('%Y-%m')

# %%
# The combination of the two dataframes appends media investment for each month in each state to the sales train

sales_train1 = sales_train1.copy().merge(media_monthly, on=['year_month','customer_state'], how='left')

sales_test1 = sales_test1.copy().merge(media_monthly, on=['year_month','customer_state'], how='left')

combined_df1 = combined_df1.copy().merge(media_monthly, on=['year_month','customer_state'], how='left')

# %%
sales_train1
# Out:
#                                  store_id sales_channel customer_state  \
# 0        536fcc1021bff60edb212ca9b2480757         Store            NSW
# 1        151e50feaf21b61cf23e0b944abebe28         Store            VIC
# 2        b94d71e6bc4cc21ffbaaef5e4aca6f03         Store            QLD
# 3        336e7e53cf0e3fbc9eb41bfaf6dc4847         Store             SA
# 4        97012ce84c33e28732cb5f12bb92363c         Store            VIC
# ...                                   ...           ...            ...
# 1814015  17b4adf18100c8673e3f2c72dff87722         Store            QLD
# 1814016  b16365302aa017bfadf5b34a84a84e45         Store             WA
# 1814017  d0f1c52a0107bd8707444bbf130a0234         Store             WA
# 1814018  408b7c8ad06e4d9954fa2d948a01f508         Store            NSW
# 1814019  e85984bd537ecc6d027b43bef22e4f12         Store            NSW
#
#          customer_postcode            price_lifestage_segment  customer_count  \
# 0                   2550.0                Budget-New Families              51
# 1                   3222.0                    Budget-Retirees               8
# 2                   4101.0   Mainstream-Young Singles/Couples              10
# 3                   5253.0          Mainstream-Young Families              79
# 4                   3064.0               Premium-New Families              58
# ...                    ...                                ...             ...
# 1814015             4220.0  Mainstream-Midage Singles/Couples               8
# 1814016             6066.0                Mainstream-Retirees              42
# 1814017             6170.0  Mainstream-Midage Singles/Couples              29
# 1814018             2769.0   Mainstream-Older Singles/Couples              32
# 1814019             2566.0            Mainstream-New Families              24
#
#          transaction_count  total_sale_value_x  total_sale_value_ex_gst_x  \
# 0                       77             6691.29                    6146.98
# 1                        8              364.53                     331.40
# 2                       11              446.25                     405.69
# 3                      119             7479.89                    6817.90
# 4                       84             6172.44                    5630.27
# ...                    ...                 ...                        ...
# 1814015                  9              710.79                     646.18
# 1814016                 46             2064.05                    1886.07
# 1814017                 37             1795.17                    1634.68
# 1814018                 38             2141.80                    1973.61
# 1814019                 28             1408.87                    1282.54
#
#          total_promotional_sales_value_x  ... store_latitude store_longitude  \
# 0                                1545.78  ...       -36.6785        149.8398
# 1                                  89.72  ...       -38.1467        144.3587
# 2                                   9.75  ...       -27.5600        153.0811
# 3                                1365.50  ...       -35.1183        139.2747
# 4                                 508.59  ...       -37.5939        144.9103
# ...                                  ...  ...            ...             ...
# 1814015                           319.40  ...       -28.0805        153.3836
# 1814016                           268.02  ...       -31.8720        115.8592
# 1814017                           170.20  ...       -32.2476        115.8123
# 1814018                           204.08  ...       -33.6917        150.9247
# 1814019                           103.17  ...       -34.0735        150.8006
#
#          co_location_flag  distance_to_kmart  distance_to_target  \
# 0                    True              >5 KM               >5 KM
# 1                    True             1-3 KM         Same Centre
# 2                    True        Same Centre         Same Centre
# 3                    True              >5 KM               >5 KM
# 4                    True        Same Centre               >5 KM
# ...                   ...                ...                 ...
# 1814015              True        Same Centre         Same Centre
# 1814016              True        Same Centre              3-5 KM
# 1814017              True              >5 KM               >5 KM
# 1814018              True        Same Centre               >5 KM
# 1814019              True        Same Centre         Same Centre
#
#          total_sale_value_y total_promotional_sales_value_y  \
# 0               38132622.27                      5879501.90
# 1               57694483.90                      7166089.98
# 2               92482637.90                      9571752.04
# 3               42636413.34                      6131102.71
# 4               54545504.41                      7088165.04
# ...                     ...                             ...
# 1814015         90359604.31                      9031217.55
# 1814016         60844174.39                      7251128.76
# 1814017         59498612.01                      6925746.81
# 1814018         92531636.15                     10145143.98
# 1814019         98868058.14                     10426260.60
#
#         total_sale_value_ex_gst_y  year_month  media_amount_spend
# 0                     34759019.81     2023-03         6180823.875
# 1                     52597105.02     2022-01         3209616.050
# 2                     84342899.73     2023-03         2876333.925
# 3                     38922466.04     2023-01          356125.960
# 4                     49733005.77     2021-11         1335517.270
# ...                           ...         ...                 ...
# 1814015               82398417.91     2021-07         4161605.600
# 1814016               55488379.89     2022-12          299486.440
# 1814017               54288917.48     2022-02         1605819.910
# 1814018               84402708.86     2022-12         1066955.210
# 1814019               90277026.79     2023-01         2152754.460
#
# [1814020 rows x 23 columns]

# %%
aa = pd.DataFrame(combined_df1.groupby(['year_month','customer_state'])['total_sale_value_x'].sum().round(1).reset_index())
bb = pd.DataFrame(combined_df1.groupby(['year_month'])['total_sale_value_x'].sum().round(1).reset_index())

# %%
# media investment seems unable to boom sales, total sales value increase since September to December each year 
plt.figure(figsize=(10, 6))
plt.plot(bb['year_month'], bb['total_sale_value_x'], marker='o', linestyle='-')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 6))  # Set the figure size
sns.lineplot(data=media_monthly, x='year_month', y='media_amount_spend', hue='customer_state', marker='o', palette='Set1')
plt.xticks(rotation = 90)

plt.show()

#确定趋势，图下面EDA还会出现

# %%
country_media_monthly = pd.DataFrame(media_monthly.groupby(['year_month'])['media_amount_spend'].sum().round(2)).reset_index()

# months_to_exclude = ['2021-01', '2021-02', '2021-03', '2021-04', '2021-05', '2021-06', '2023-08', '2023-12']
# country_media_monthly = country_media_monthly[~country_media_monthly['year_month'].isin(months_to_exclude)]

country_media_monthly
# Out:
#    year_month  media_amount_spend
# 0     2021-01          7727951.64
# 1     2021-02         11435681.60
# 2     2021-03         12910751.88
# 3     2021-04         14985961.65
# 4     2021-05         18588916.50
# 5     2021-06         12706990.06
# 6     2021-07         20747695.85
# 7     2021-08          1928998.97
# 8     2021-09          1413426.71
# 9     2021-10          2926143.84
# 10    2021-11          5762788.21
# 11    2021-12          3771670.80
# 12    2022-01         12696137.05
# 13    2022-02         19546997.18
# 14    2022-03         18061342.63
# 15    2022-04         23529888.26
# 16    2022-05          9322625.94
# 17    2022-06         35282929.59
# 18    2022-07          8663279.25
# 19    2022-08          1632535.46
# 20    2022-09          2678313.40
# 21    2022-10          5035235.81
# 22    2022-11          7246935.99
# 23    2022-12          2914111.07
# 24    2023-01          5910020.37
# 25    2023-02          1993277.27
# 26    2023-03         15486047.26
# 27    2023-04         19257924.96
# 28    2023-05          5175421.86
# 29    2023-08           838882.14
# 30    2023-12          1157684.08

# %%
country_media_monthly['month'] = pd.to_datetime(country_media_monthly['year_month']).dt.strftime('%m')

# Group the data by 'month' and calculate the mean 'media_amount_spend'
result = country_media_monthly.groupby('month')['media_amount_spend'].mean().reset_index()

# Sort the result by 'month' if needed
result = pd.DataFrame(result.sort_values(by='month').round(2))

# Display the result
(result['media_amount_spend']/ 23994959.83).round(2)
# Out:
# 0     0.37
# 1     0.46
# 2     0.65
# 3     0.80
# 4     0.46
# 5     1.00
# 6     0.61
# 7     0.06
# 8     0.09
# 9     0.17
# 10    0.27
# 11    0.11
# Name: media_amount_spend, dtype: float64

# %%
total_sales_monthly = pd.DataFrame(sales_train1.groupby(['year_month'])['total_sale_value_x'].sum().round(2)).reset_index()
total_sales_monthly
# Out:
#    year_month  total_sale_value_x
# 0     2021-07        8.983052e+07
# 1     2021-08        8.916955e+07
# 2     2021-09        7.114335e+07
# 3     2021-10        1.277387e+08
# 4     2021-11        1.579087e+08
# 5     2021-12        2.283428e+08
# 6     2022-01        1.205917e+08
# 7     2022-02        1.002265e+08
# 8     2022-03        1.082580e+08
# 9     2022-04        1.264944e+08
# 10    2022-05        1.458877e+08
# 11    2022-06        1.404081e+08
# 12    2022-07        1.539431e+08
# 13    2022-08        1.132336e+08
# 14    2022-09        1.154995e+08
# 15    2022-10        1.508010e+08
# 16    2022-11        1.654228e+08
# 17    2022-12        2.484433e+08
# 18    2023-01        1.474819e+08
# 19    2023-02        1.117813e+08
# 20    2023-03        1.113064e+08
# 21    2023-04        1.613865e+08
# 22    2023-05        7.113654e+07

# %%
total_sales_monthly['month'] = pd.to_datetime(total_sales_monthly['year_month']).dt.strftime('%m')

# Group the data by 'month' and calculate the mean 'media_amount_spend'
result = total_sales_monthly.groupby('month')['total_sale_value_x'].mean().reset_index()

# Sort the result by 'month' if needed
result = pd.DataFrame(result.sort_values(by='month').round(1))

# Display the result
(result['total_sale_value_x']/ 238393041.4).round(2)
# Out:
# 0     0.56
# 1     0.44
# 2     0.46
# 3     0.60
# 4     0.46
# 5     0.59
# 6     0.51
# 7     0.42
# 8     0.39
# 9     0.58
# 10    0.68
# 11    1.00
# Name: total_sale_value_x, dtype: float64

# %% [markdown]
# ### Feature Engineering

# %%
month_to_value = {
    1: 0.56,   # January
    2: 0.44, # February
    3: 0.46,   # March
    4: 0.60, # April
    5: 0.46, # May
    6: 0.59, # June
    7: 0.51, # July
    8: 0.42, # August
    9: 0.39, # September
    10: 0.58, # October
    11: 0.68, # November
    12: 1.00  # December
}


sales_train1['year_month'] = pd.to_datetime(sales_train1['year_month'])
sales_test1['year_month'] = pd.to_datetime(sales_test1['year_month'])

# Create a new column based on the mapping
sales_train1['year_month_sales'] = sales_train1['year_month'].dt.month.map(month_to_value)

sales_test1['year_month_sales'] = sales_test1['year_month'].dt.month.map(month_to_value)


combined_df1['year_month'] = pd.to_datetime(combined_df1['year_month'])
combined_df1['year_month_sales'] = combined_df1['year_month'].dt.month.map(month_to_value)

# %% [markdown]
# <span style='color:green'> **Convert different month for mutiple years to numerical based on the trend of total sales value accross years, which can be used directly and effectively as a viarble in OLS. However, I've tried to assign numerical values to month based on media amount spend on each month, the result turns out to be unexplainable due to extreme low correlation with sales and low t-value in the OLS** </span>

# %%
sales_train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1814020 entries, 0 to 1814019
# Data columns (total 24 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   store_id                         object
#  1   sales_channel                    object
#  2   customer_state                   object
#  3   customer_postcode                float64
#  4   price_lifestage_segment          object
#  5   customer_count                   int64
#  6   transaction_count                int64
#  7   total_sale_value_x               float64
#  8   total_sale_value_ex_gst_x        float64
#  9   total_promotional_sales_value_x  float64
#  10  financial_week_end_date          datetime64[ns]
#  11  store_state                      object
#  12  store_postcode                   int64
#  13  store_latitude                   float64
#  14  store_longitude                  float64
#  15  co_location_flag                 bool
#  16  distance_to_kmart                object
#  17  distance_to_target               object
#  18  total_sale_value_y               float64
#  19  total_promotional_sales_value_y  float64
#  20  total_sale_value_ex_gst_y        float64
#  21  year_month                       datetime64[ns]
#  22  media_amount_spend               float64
#  23  year_month_sales                 float64
# dtypes: bool(1), datetime64[ns](2), float64(11), int64(3), object(7)
# memory usage: 333.9+ MB

# %%
def extract_segment1(value):
    if value:
        if "new families" in value.lower():
            return "New Families"
        elif "retirees" in value.lower():
            return "Retirees"
        elif "older singles/couples" in value.lower():
            return "Older Singles/Couples"
        elif "young singles/couples" in value.lower():
            return "Young Singles/Couples"
        elif "young families" in value.lower():
            return "Young Families"
        elif "older families" in value.lower():
            return "Older Families"
        elif "midage singles/couples" in value.lower():
            return "Midage Singles/Couples"
    return None

sales_train1['segment'] = sales_train1['price_lifestage_segment'].apply(extract_segment1)
sales_test1['segment'] = sales_test1['price_lifestage_segment'].apply(extract_segment1)
combined_df1['segment'] = combined_df1['price_lifestage_segment'].apply(extract_segment1)

# %%
def extract_segment(value):
    if value:
        if "budget" in value.lower():
            return "Budget"
        elif "premium" in value.lower():
            return "Premium"
        elif "mainstream" in value.lower():
            return "Mainstream"
    return None

sales_train1['main_segment'] = sales_train1['price_lifestage_segment'].apply(extract_segment)
sales_test1['main_segment'] = sales_test1['price_lifestage_segment'].apply(extract_segment)
combined_df1['main_segment'] = combined_df1['price_lifestage_segment'].apply(extract_segment)

# %%
# Distance to Target and Kmart 

def set_distance_kmart(distance):
    if distance == '1-3 KM':
        return 0.87
    elif distance == '3-5 KM':
        return 0.79
    elif distance == '<1 KM':
        return 0.95
    elif distance == '>5 KM':
        return 1
    elif distance == 'Same Centre':
        return 0.66
    else:
        return None  # Set to None for values that don't match the conditions
    
def set_distance_target(distance):
    if distance == '1-3 KM':
        return 0.96
    elif distance == '3-5 KM':
        return 0.77
    elif distance == '<1 KM':
        return 1
    elif distance == '>5 KM':
        return 0.94
    elif distance == 'Same Centre':
        return 0.73
    else:
        return None

# Apply the custom function to the 'distance_km' column
sales_train1['distance_kmart'] = sales_train1['distance_to_kmart'].apply(set_distance_kmart)
sales_train1['distance_target'] = sales_train1['distance_to_target'].apply(set_distance_target)

sales_test1['distance_kmart'] = sales_test1['distance_to_kmart'].apply(set_distance_kmart)
sales_test1['distance_target'] = sales_test1['distance_to_target'].apply(set_distance_target)

sales_train1['distance_kmart_target']=sales_train1['distance_kmart']*sales_train1['distance_target']
sales_test1['distance_kmart_target']=sales_test1['distance_kmart']*sales_test1['distance_target']



combined_df1['distance_kmart'] = combined_df1['distance_to_kmart'].apply(set_distance_kmart)
combined_df1['distance_target'] = combined_df1['distance_to_target'].apply(set_distance_target)
combined_df1['distance_kmart_target']=combined_df1['distance_kmart']*sales_test1['distance_target']

# %%
# co_location_flag

def set_values1(co):
    if co == True:
        return 0.68
    elif co == False:
        return 1
    else:
        return None  # Set to None for values that don't match the conditions
sales_train1['co'] = sales_train1['co_location_flag'].apply(set_values1)
# sales_train1['co'] = sales_train1['co_location_flag'].apply(set_values1)
sales_test1['co'] = sales_test1['co_location_flag'].apply(set_values1)
combined_df1['co'] = combined_df1['co_location_flag'].apply(set_values1)

# %%
# price_lifestage_segment

def set_lifestage_segments(segment):
    if segment == 'Budget-Midage Singles/Couples':
        return 0.44
    elif segment == 'Budget-New Families':
        return 0.75
    elif segment == 'Budget-Older Families':
        return 0.62
    elif segment == 'Budget-Older Singles/Couples':
        return 0.62
    elif segment == 'Budget-Retirees':
        return 0.43
    elif segment == 'Budget-Young Families':
        return 1
    elif segment == 'Budget-Young Singles/Couples':
        return 0.52
    
    elif segment == 'Mainstream-Midage Singles/Couples':
        return 0.37
    elif segment == 'Mainstream-New Families':
        return 0.51
    elif segment == 'Mainstream-Older Families':
        return 0.48
    elif segment == 'Mainstream-Older Singles/Couples':
        return 0.63
    elif segment == 'Mainstream-Retirees':
        return 0.53
    elif segment == 'Mainstream-Young Families':
        return 0.73
    elif segment == 'Mainstream-Young Singles/Couples':
        return 0.41
    
    elif segment == 'Premium-Midage Singles/Couples':
        return 0.27
    elif segment == 'Premium-New Families':
        return 0.34
    elif segment == 'Premium-Older Families':
        return 0.3
    elif segment == 'Premium-Older Singles/Couples':
        return 0.43
    elif segment == 'Premium-Retirees':
        return 0.38
    elif segment == 'Premium-Young Families':
        return 0.51
    elif segment == 'Premium-Young Singles/Couples':
        return 0.25
 
    else:
        return None  

    
sales_train1['price_lifestage_segment_num'] = sales_train1['price_lifestage_segment'].apply(set_lifestage_segments)

sales_test1['price_lifestage_segment_num'] = sales_test1['price_lifestage_segment'].apply(set_lifestage_segments)
combined_df1['price_lifestage_segment_num'] = combined_df1['price_lifestage_segment'].apply(set_lifestage_segments)

# %%
# main_segment

def set_main_segments(segment):
    if segment == 'Budget':
        return 1
    elif segment == 'Premium':
        return 0.56
    elif segment == 'Mainstream':
        return 0.81
    else:
        return None

sales_train1['main_segment_num'] = sales_train1['main_segment'].apply(set_main_segments)
sales_test1['main_segment_num'] = sales_test1['main_segment'].apply(set_main_segments)
combined_df1['main_segment_num'] = combined_df1['main_segment'].apply(set_main_segments)

# %%
# segment

def set_segments(segment):
    if segment == 'Midage Singles/Couples':
        return 0.45
    elif segment == 'New Families':
        return 0.72
    elif segment == 'Older Families':
        return 0.64
    elif segment == 'Older Singles/Couples':
        return 0.72
    elif segment == 'Retirees':
        return 0.57
    elif segment == 'Young Families':
        return 1
    elif segment == 'Young Singles/Couples':
        return 0.52
 
    else:
        return None  

    
sales_train1['segment_num'] = sales_train1['segment'].apply(set_segments)

sales_test1['segment_num'] = sales_test1['segment'].apply(set_segments)
combined_df1['segment_num'] = combined_df1['segment'].apply(set_segments)

# %%
# state

def set_states(state):
    if state == 'ACT':
        return 0.58
    elif state == 'NSW':
        return 1
    elif state == 'NT':
        return 0.86
    elif state == 'QLD':
        return 0.98
    elif state == 'SA':
        return 0.71
    elif state == 'TAS':
        return 0.8
    elif state == 'VIC':
        return 0.75
    elif state == 'WA':
        return 0.85
    else:
        return None
    
    
sales_train1['state_num'] = sales_train1['customer_state'].apply(set_states)
sales_test1['state_num'] = sales_test1['customer_state'].apply(set_states)
combined_df1['state_num'] = combined_df1['customer_state'].apply(set_states)

# %%
# Sales Channel (目前转变为数字形式不准确)

def set_channel(channel):
    if channel == 'Digital - ClickCollect':
        return 0.74
    elif channel == 'Digital - Delivery':
        return 0.42
    elif channel == 'Store':
        return 1
    else:
        return None 
    
sales_train1['channel_num'] = sales_train1['sales_channel'].apply(set_channel)

sales_test1['channel_num'] = sales_test1['sales_channel'].apply(set_channel)

combined_df1['channel_num'] = combined_df1['sales_channel'].apply(set_channel)

# %%
# segment * sales channel 

sales_train1['price_lifestage_segment_channel_num'] = sales_train1['channel_num']*sales_train1['price_lifestage_segment_num']
sales_test1['price_lifestage_segment_channel_num'] = sales_test1['channel_num']*sales_test1['price_lifestage_segment_num']

combined_df1['price_lifestage_segment_channel_num'] = combined_df1['channel_num']*combined_df1['price_lifestage_segment_num']

# %%
sales_train1['price_lifestage_segment_channel'] = sales_train1['channel_num'] * sales_train1['price_lifestage_segment_num']

sales_test1['price_lifestage_segment_channel'] = sales_test1['channel_num'] * sales_test1['price_lifestage_segment_num']

combined_df1['price_lifestage_segment_channel'] = combined_df1['channel_num'] * sales_test1['price_lifestage_segment_num']

# %%
# state & price_lifestate_segment

sales_train1['state_lifestage'] = sales_train1['state_num']*sales_train1['price_lifestage_segment_num']

sales_test1['state_lifestage'] = sales_test1['state_num']*sales_test1['price_lifestage_segment_num']

combined_df1['state_lifestage'] = combined_df1['state_num']*sales_test1['price_lifestage_segment_num']

# %%
sales_train1['promotional_price_lifestage_segment'] = sales_train1['price_lifestage_segment_num']*sales_train1['total_promotional_sales_value_x']
# sales_train1['promotional_segment'] = sales_train1['segment_num']*sales_train1['total_promotional_sales_value_x']
# sales_train1['promotional_main_segment'] = sales_train1['main_segment_num']*sales_train1['total_promotional_sales_value_x']

sales_train1['state_promotional'] = sales_train1['state_num']*sales_train1['total_promotional_sales_value_x']


sales_test1['promotional_price_lifestage_segment'] = sales_test1['price_lifestage_segment_num']*sales_test1['total_promotional_sales_value_x']
# sales_train1['promotional_segment'] = sales_train1['segment_num']*sales_train1['total_promotional_sales_value_x']
# sales_train1['promotional_main_segment'] = sales_train1['main_segment_num']*sales_train1['total_promotional_sales_value_x']

sales_test1['state_promotional'] = sales_test1['state_num']*sales_test1['total_promotional_sales_value_x']


combined_df1['promotional_price_lifestage_segment'] = combined_df1['price_lifestage_segment_num']*combined_df1['total_promotional_sales_value_x']
combined_df1['state_promotional'] = combined_df1['state_num']*combined_df1['total_promotional_sales_value_x']

# %% [markdown]
# ### EDA

# %%
# Create a heatmap of correlations between variables

plt.figure(figsize=(15, 12))
sns.heatmap(sales_train1.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
plt.figure(figsize=(18, 6))

plt.subplot(1, 2, 1)
sns.lineplot(data=media_monthly, x='year_month', y='media_amount_spend', hue='customer_state', marker='o', palette='Set1')
plt.xticks(rotation=90)
plt.title('Media Amount Spend by Customer State')
plt.xlabel('Year-Month')
plt.ylabel('Media Amount Spend')

plt.subplot(1, 2, 2)
sns.lineplot(data=aa, x='year_month', y='total_sale_value_x', hue='customer_state', marker='o', palette='Set1')
plt.xticks(rotation=90)
plt.title('Total Sales Value Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Total Sales Value')

plt.tight_layout()
plt.show()


# media investment gets larger in the month of sales trough(January to July each year), much lesser media investment 
# in sales peak(September to December)

# %%
plt.figure(figsize=(40,20))
media.boxplot(column='media_amount_spend',by = 'state')
plt.title('Distribution of Media investment by States')
plt.xlabel('States')
plt.ylabel('Media Investment Amount($)(Log-Scale)')
plt.yscale("log")
plt.tight_layout()
plt.savefig('2.pdf')

# %%
sns.scatterplot(data=combined_df1, x='customer_count', y='total_sale_value_x',hue='main_segment', marker='o', palette='Set1',alpha=0.5)
# Out:
# <AxesSubplot:xlabel='customer_count', ylabel='total_sale_value_x'>

# %%
sales_train1['log_total_sale_value_x'] = np.log(sales_train1['total_sale_value_x'] + 1)  # +1 to avoid log(0)
sns.boxplot(x='co', y='log_total_sale_value_x', data=sales_train1)
plt.title('Boxplot of log-transformed total_sale_value_x for Different Values of co')
plt.show()

# %%
plt.figure(figsize=(12, 6))
palette = sns.color_palette("hsv", len(sales_train1['customer_state'].unique()))
for idx, st in enumerate(sales_train1['customer_state'].unique()):
    sns.histplot(sales_train1['log_total_sale_value_x'][sales_train1['customer_state'] == st], 
                 kde=True, 
                 color=palette[idx],
                 label=str(st), 
                 alpha=0.5)  # alpha for transparency
plt.title('Distribution of log_total_sale_value_x for Different States')
plt.xlabel('Log Total Sale Value X')
plt.ylabel('Density')
plt.legend(title='State')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

categorical_vars = ['price_lifestage_segment_num', 'channel_num', 'distance_kmart', 'distance_target', 'distance_kmart_target']

for var in categorical_vars:
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=var, y='log_total_sale_value_x', data=sales_train1)
    plt.title(f'Boxplot of log_total_sale_value_x across {var}')
    plt.xlabel(var)
    plt.ylabel('log_total_sale_value_x')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
sales_train1['financial_week_end_date'] = pd.to_datetime(sales_train1['financial_week_end_date'])

grouped_total_sale = sales_train1.groupby('financial_week_end_date').agg({'total_sale_value_x': 'sum'}).reset_index()
grouped_sorted_total_sale = grouped_total_sale.sort_values(by='financial_week_end_date')

grouped_promo_sale = sales_train1.groupby('financial_week_end_date').agg({'total_promotional_sales_value_x': 'sum'}).reset_index()
grouped_sorted_promo_sale = grouped_promo_sale.sort_values(by='financial_week_end_date')

plt.figure(figsize=(10,5))
plt.plot(grouped_sorted_total_sale['financial_week_end_date'], grouped_sorted_total_sale['total_sale_value_x'], label='Total Sale Value')
plt.plot(grouped_sorted_promo_sale['financial_week_end_date'], grouped_sorted_promo_sale['total_promotional_sales_value_x'], label='Promotional Sale Value', linestyle='--')
plt.title('Total Sale and Promotional Sale Value Over Time')
plt.xlabel('Date')
plt.ylabel('Value ($)(Log Scale)')
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('13.pdf')

# %% [markdown]
# ### Model Tranining

# %%
sales_train1.corr()
# Out:
#                                      customer_postcode  customer_count  \
# customer_postcode                             1.000000        0.003265
# customer_count                                0.003265        1.000000
# transaction_count                             0.002995        0.990485
# total_sale_value_x                           -0.007186        0.928959
# total_sale_value_ex_gst_x                    -0.007140        0.928534
# total_promotional_sales_value_x              -0.003394        0.815632
# store_postcode                                0.992568        0.005137
# store_latitude                                0.035851        0.056973
# store_longitude                              -0.601737        0.011630
# co_location_flag                              0.025506       -0.031558
# total_sale_value_y                            0.000737        0.013863
# total_promotional_sales_value_y               0.133101        0.010713
# total_sale_value_ex_gst_y                     0.001165        0.014041
# media_amount_spend                           -0.387120        0.012053
# year_month_sales                             -0.020721        0.032993
# distance_kmart                               -0.035632        0.076600
# distance_target                              -0.126581        0.052075
# distance_kmart_target                        -0.074469        0.077139
# co                                           -0.025506        0.031558
# price_lifestage_segment_num                   0.024153        0.129498
# main_segment_num                              0.037849        0.079213
# segment_num                                  -0.001424        0.086688
# state_num                                    -0.314666        0.068888
# channel_num                                   0.038534        0.057657
# price_lifestage_segment_channel_num           0.029841        0.141646
# price_lifestage_segment_channel               0.029841        0.141646
# state_lifestage                              -0.098348        0.145847
# promotional_price_lifestage_segment           0.000047        0.741342
# state_promotional                            -0.026732        0.811378
# log_total_sale_value_x                       -0.013062        0.752864
#
#                                      transaction_count  total_sale_value_x  \
# customer_postcode                             0.002995           -0.007186
# customer_count                                0.990485            0.928959
# transaction_count                             1.000000            0.952650
# total_sale_value_x                            0.952650            1.000000
# total_sale_value_ex_gst_x                     0.952302            0.999980
# total_promotional_sales_value_x               0.848034            0.876994
# store_postcode                                0.005136           -0.005612
# store_latitude                                0.055892            0.063328
# store_longitude                               0.013749            0.025366
# co_location_flag                             -0.042456           -0.061943
# total_sale_value_y                            0.001115            0.006927
# total_promotional_sales_value_y              -0.001919            0.002121
# total_sale_value_ex_gst_y                     0.001298            0.007137
# media_amount_spend                            0.011463            0.015866
# year_month_sales                              0.039325            0.081216
# distance_kmart                                0.092340            0.106023
# distance_target                               0.062551            0.072570
# distance_kmart_target                         0.093538            0.108627
# co                                            0.042456            0.061943
# price_lifestage_segment_num                   0.144988            0.205092
# main_segment_num                              0.101418            0.124728
# segment_num                                   0.091833            0.152067
# state_num                                     0.069398            0.082775
# channel_num                                   0.057288            0.024881
# price_lifestage_segment_channel_num           0.157423            0.212740
# price_lifestage_segment_channel               0.157423            0.212740
# state_lifestage                               0.160586            0.222313
# promotional_price_lifestage_segment           0.782489            0.842220
# state_promotional                             0.844729            0.877643
# log_total_sale_value_x                        0.746835            0.749653
#
#                                      total_sale_value_ex_gst_x  \
# customer_postcode                                    -0.007140
# customer_count                                        0.928534
# transaction_count                                     0.952302
# total_sale_value_x                                    0.999980
# total_sale_value_ex_gst_x                             1.000000
# total_promotional_sales_value_x                       0.876758
# store_postcode                                       -0.005567
# store_latitude                                        0.063244
# store_longitude                                       0.025401
# co_location_flag                                     -0.061910
# total_sale_value_y                                    0.006916
# total_promotional_sales_value_y                       0.002104
# total_sale_value_ex_gst_y                             0.007127
# media_amount_spend                                    0.015566
# year_month_sales                                      0.081859
# distance_kmart                                        0.105881
# distance_target                                       0.072486
# distance_kmart_target                                 0.108489
# co                                                    0.061910
# price_lifestage_segment_num                           0.204941
# main_segment_num                                      0.124849
# segment_num                                           0.151764
# state_num                                             0.082721
# channel_num                                           0.025061
# price_lifestage_segment_channel_num                   0.212620
# price_lifestage_segment_channel                       0.212620
# state_lifestage                                       0.222158
# promotional_price_lifestage_segment                   0.841985
# state_promotional                                     0.877431
# log_total_sale_value_x                                0.749358
#
#                                      total_promotional_sales_value_x  \
# customer_postcode                                          -0.003394
# customer_count                                              0.815632
# transaction_count                                           0.848034
# total_sale_value_x                                          0.876994
# total_sale_value_ex_gst_x                                   0.876758
# total_promotional_sales_value_x                             1.000000
# store_postcode                                             -0.001657
# store_latitude                                              0.038754
# store_longitude                                             0.015771
# co_location_flag                                           -0.054790
# total_sale_value_y                                         -0.016163
# total_promotional_sales_value_y                            -0.012124
# total_sale_value_ex_gst_y                                  -0.016006
# media_amount_spend                                          0.007613
# year_month_sales                                            0.033695
# distance_kmart                                              0.091757
# distance_target                                             0.058528
# distance_kmart_target                                       0.092056
# co                                                          0.054790
# price_lifestage_segment_num                                 0.208980
# main_segment_num                                            0.172470
# segment_num                                                 0.122969
# state_num                                                   0.055606
# channel_num                                                 0.066257
# price_lifestage_segment_channel_num                         0.224303
# price_lifestage_segment_channel                             0.224303
# state_lifestage                                             0.214415
# promotional_price_lifestage_segment                         0.958913
# state_promotional                                           0.991474
# log_total_sale_value_x                                      0.646294
#
#                                      store_postcode  store_latitude  \
# customer_postcode                          0.992568        0.035851
# customer_count                             0.005137        0.056973
# transaction_count                          0.005136        0.055892
# total_sale_value_x                        -0.005612        0.063328
# total_sale_value_ex_gst_x                 -0.005567        0.063244
# total_promotional_sales_value_x           -0.001657        0.038754
# store_postcode                             1.000000        0.039568
# store_latitude                             0.039568        1.000000
# store_longitude                           -0.606207        0.080629
# co_location_flag                           0.019492        0.044436
# total_sale_value_y                        -0.009776        0.045026
# total_promotional_sales_value_y            0.125918       -0.019261
# total_sale_value_ex_gst_y                 -0.009323        0.045231
# media_amount_spend                        -0.386391       -0.072520
# year_month_sales                          -0.021486       -0.021742
# distance_kmart                            -0.029511        0.053410
# distance_target                           -0.122800       -0.047991
# distance_kmart_target                     -0.067970        0.015657
# co                                        -0.019492       -0.044436
# price_lifestage_segment_num                0.022900        0.009123
# main_segment_num                           0.036931        0.028142
# segment_num                               -0.002128       -0.009655
# state_num                                 -0.305052        0.500420
# channel_num                                0.040055        0.020747
# price_lifestage_segment_channel_num        0.028919        0.012358
# price_lifestage_segment_channel            0.028919        0.012358
# state_lifestage                           -0.095701        0.193666
# promotional_price_lifestage_segment        0.001222        0.031924
# state_promotional                         -0.024678        0.069795
# log_total_sale_value_x                    -0.011179        0.075237
#
#                                      store_longitude  co_location_flag  ...  \
# customer_postcode                          -0.601737          0.025506  ...
# customer_count                              0.011630         -0.031558  ...
# transaction_count                           0.013749         -0.042456  ...
# total_sale_value_x                          0.025366         -0.061943  ...
# total_sale_value_ex_gst_x                   0.025401         -0.061910  ...
# total_promotional_sales_value_x             0.015771         -0.054790  ...
# store_postcode                             -0.606207          0.019492  ...
# store_latitude                              0.080629          0.044436  ...
# store_longitude                             1.000000         -0.068312  ...
# co_location_flag                           -0.068312          1.000000  ...
# total_sale_value_y                         -0.000732          0.218405  ...
# total_promotional_sales_value_y            -0.109883          0.232711  ...
# total_sale_value_ex_gst_y                  -0.000426          0.218072  ...
# media_amount_spend                          0.267242         -0.047824  ...
# year_month_sales                            0.008324          0.006219  ...
# distance_kmart                              0.078551         -0.196509  ...
# distance_target                            -0.036922         -0.221289  ...
# distance_kmart_target                       0.038201         -0.246373  ...
# co                                          0.068312         -1.000000  ...
# price_lifestage_segment_num                 0.005064         -0.022660  ...
# main_segment_num                            0.014181         -0.037983  ...
# segment_num                                -0.004655          0.002191  ...
# state_num                                   0.405523         -0.019030  ...
# channel_num                                -0.031339          0.009745  ...
# price_lifestage_segment_channel_num         0.000213         -0.021345  ...
# price_lifestage_segment_channel             0.000213         -0.021345  ...
# state_lifestage                             0.156817         -0.027232  ...
# promotional_price_lifestage_segment         0.014062         -0.045159  ...
# state_promotional                           0.044012         -0.055091  ...
# log_total_sale_value_x                      0.022643         -0.076743  ...
#
#                                      main_segment_num  segment_num  state_num  \
# customer_postcode                            0.037849    -0.001424  -0.314666
# customer_count                               0.079213     0.086688   0.068888
# transaction_count                            0.101418     0.091833   0.069398
# total_sale_value_x                           0.124728     0.152067   0.082775
# total_sale_value_ex_gst_x                    0.124849     0.151764   0.082721
# total_promotional_sales_value_x              0.172470     0.122969   0.055606
# store_postcode                               0.036931    -0.002128  -0.305052
# store_latitude                               0.028142    -0.009655   0.500420
# store_longitude                              0.014181    -0.004655   0.405523
# co_location_flag                            -0.037983     0.002191  -0.019030
# total_sale_value_y                           0.002942     0.013424   0.156553
# total_promotional_sales_value_y              0.014364     0.018031   0.032023
# total_sale_value_ex_gst_y                    0.003220     0.013432   0.157058
# media_amount_spend                           0.000202     0.003685   0.302040
# year_month_sales                            -0.010518    -0.004326  -0.005814
# distance_kmart                               0.053944    -0.004224   0.010065
# distance_target                             -0.012719    -0.002088  -0.001046
# distance_kmart_target                        0.034227    -0.004023  -0.000827
# co                                           0.037983    -0.002191   0.019030
# price_lifestage_segment_num                  0.609417     0.740596   0.022268
# main_segment_num                             1.000000     0.053299   0.033466
# segment_num                                  0.053299     1.000000   0.006364
# state_num                                    0.033466     0.006364   1.000000
# channel_num                                 -0.092144    -0.122022  -0.030249
# price_lifestage_segment_channel_num          0.602718     0.729096   0.017779
# price_lifestage_segment_channel              0.602718     0.729096   0.017779
# state_lifestage                              0.567835     0.677912   0.388001
# promotional_price_lifestage_segment          0.200336     0.202921   0.045210
# state_promotional                            0.167892     0.119179   0.116370
# log_total_sale_value_x                       0.134625     0.188128   0.102502
#
#                                      channel_num  \
# customer_postcode                       0.038534
# customer_count                          0.057657
# transaction_count                       0.057288
# total_sale_value_x                      0.024881
# total_sale_value_ex_gst_x               0.025061
# total_promotional_sales_value_x         0.066257
# store_postcode                          0.040055
# store_latitude                          0.020747
# store_longitude                        -0.031339
# co_location_flag                        0.009745
# total_sale_value_y                     -0.033210
# total_promotional_sales_value_y        -0.024729
# total_sale_value_ex_gst_y              -0.033309
# media_amount_spend                      0.017891
# year_month_sales                       -0.001565
# distance_kmart                         -0.022183
# distance_target                        -0.019049
# distance_kmart_target                  -0.023927
# co                                     -0.009745
# price_lifestage_segment_num            -0.164169
# main_segment_num                       -0.092144
# segment_num                            -0.122022
# state_num                              -0.030249
# channel_num                             1.000000
# price_lifestage_segment_channel_num     0.006366
# price_lifestage_segment_channel         0.006366
# state_lifestage                        -0.164578
# promotional_price_lifestage_segment     0.048975
# state_promotional                       0.063683
# log_total_sale_value_x                  0.008826
#
#                                      price_lifestage_segment_channel_num  \
# customer_postcode                                               0.029841
# customer_count                                                  0.141646
# transaction_count                                               0.157423
# total_sale_value_x                                              0.212740
# total_sale_value_ex_gst_x                                       0.212620
# total_promotional_sales_value_x                                 0.224303
# store_postcode                                                  0.028919
# store_latitude                                                  0.012358
# store_longitude                                                 0.000213
# co_location_flag                                               -0.021345
# total_sale_value_y                                              0.003639
# total_promotional_sales_value_y                                 0.015948
# total_sale_value_ex_gst_y                                       0.003801
# media_amount_spend                                              0.004322
# year_month_sales                                               -0.010518
# distance_kmart                                                  0.030700
# distance_target                                                -0.009671
# distance_kmart_target                                           0.018598
# co                                                              0.021345
# price_lifestage_segment_num                                     0.984316
# main_segment_num                                                0.602718
# segment_num                                                     0.729096
# state_num                                                       0.017779
# channel_num                                                     0.006366
# price_lifestage_segment_channel_num                             1.000000
# price_lifestage_segment_channel                                 1.000000
# state_lifestage                                                 0.904479
# promotional_price_lifestage_segment                             0.317228
# state_promotional                                               0.217776
# log_total_sale_value_x                                          0.232538
#
#                                      price_lifestage_segment_channel  \
# customer_postcode                                           0.029841
# customer_count                                              0.141646
# transaction_count                                           0.157423
# total_sale_value_x                                          0.212740
# total_sale_value_ex_gst_x                                   0.212620
# total_promotional_sales_value_x                             0.224303
# store_postcode                                              0.028919
# store_latitude                                              0.012358
# store_longitude                                             0.000213
# co_location_flag                                           -0.021345
# total_sale_value_y                                          0.003639
# total_promotional_sales_value_y                             0.015948
# total_sale_value_ex_gst_y                                   0.003801
# media_amount_spend                                          0.004322
# year_month_sales                                           -0.010518
# distance_kmart                                              0.030700
# distance_target                                            -0.009671
# distance_kmart_target                                       0.018598
# co                                                          0.021345
# price_lifestage_segment_num                                 0.984316
# main_segment_num                                            0.602718
# segment_num                                                 0.729096
# state_num                                                   0.017779
# channel_num                                                 0.006366
# price_lifestage_segment_channel_num                         1.000000
# price_lifestage_segment_channel                             1.000000
# state_lifestage                                             0.904479
# promotional_price_lifestage_segment                         0.317228
# state_promotional                                           0.217776
# log_total_sale_value_x                                      0.232538
#
#                                      state_lifestage  \
# customer_postcode                          -0.098348
# customer_count                              0.145847
# transaction_count                           0.160586
# total_sale_value_x                          0.222313
# total_sale_value_ex_gst_x                   0.222158
# total_promotional_sales_value_x             0.214415
# store_postcode                             -0.095701
# store_latitude                              0.193666
# store_longitude                             0.156817
# co_location_flag                           -0.027232
# total_sale_value_y                          0.065910
# total_promotional_sales_value_y             0.027760
# total_sale_value_ex_gst_y                   0.066260
# media_amount_spend                          0.112714
# year_month_sales                           -0.010664
# distance_kmart                              0.037493
# distance_target                            -0.006600
# distance_kmart_target                       0.021896
# co                                          0.027232
# price_lifestage_segment_num                 0.921165
# main_segment_num                            0.567835
# segment_num                                 0.677912
# state_num                                   0.388001
# channel_num                                -0.164578
# price_lifestage_segment_channel_num         0.904479
# price_lifestage_segment_channel             0.904479
# state_lifestage                             1.000000
# promotional_price_lifestage_segment         0.297736
# state_promotional                           0.234456
# log_total_sale_value_x                      0.246706
#
#                                      promotional_price_lifestage_segment  \
# customer_postcode                                               0.000047
# customer_count                                                  0.741342
# transaction_count                                               0.782489
# total_sale_value_x                                              0.842220
# total_sale_value_ex_gst_x                                       0.841985
# total_promotional_sales_value_x                                 0.958913
# store_postcode                                                  0.001222
# store_latitude                                                  0.031924
# store_longitude                                                 0.014062
# co_location_flag                                               -0.045159
# total_sale_value_y                                             -0.011092
# total_promotional_sales_value_y                                -0.007297
# total_sale_value_ex_gst_y                                      -0.010940
# media_amount_spend                                              0.008221
# year_month_sales                                                0.023355
# distance_kmart                                                  0.075412
# distance_target                                                 0.044610
# distance_kmart_target                                           0.074220
# co                                                              0.045159
# price_lifestage_segment_num                                     0.303083
# main_segment_num                                                0.200336
# segment_num                                                     0.202921
# state_num                                                       0.045210
# channel_num                                                     0.048975
# price_lifestage_segment_channel_num                             0.317228
# price_lifestage_segment_channel                                 0.317228
# state_lifestage                                                 0.297736
# promotional_price_lifestage_segment                             1.000000
# state_promotional                                               0.950556
# log_total_sale_value_x                                          0.557450
#
#                                      state_promotional  log_total_sale_value_x
# customer_postcode                            -0.026732               -0.013062
# customer_count                                0.811378                0.752864
# transaction_count                             0.844729                0.746835
# total_sale_value_x                            0.877643                0.749653
# total_sale_value_ex_gst_x                     0.877431                0.749358
# total_promotional_sales_value_x               0.991474                0.646294
# store_postcode                               -0.024678               -0.011179
# store_latitude                                0.069795                0.075237
# store_longitude                               0.044012                0.022643
# co_location_flag                             -0.055091               -0.076743
# total_sale_value_y                           -0.006135                0.001623
# total_promotional_sales_value_y              -0.010785               -0.002114
# total_sale_value_ex_gst_y                    -0.005946                0.001773
# media_amount_spend                            0.027170                0.021741
# year_month_sales                              0.033276                0.101387
# distance_kmart                                0.092619                0.138251
# distance_target                               0.054899                0.089946
# distance_kmart_target                         0.090633                0.139470
# co                                            0.055091                0.076743
# price_lifestage_segment_num                   0.203008                0.227842
# main_segment_num                              0.167892                0.134625
# segment_num                                   0.119179                0.188128
# state_num                                     0.116370                0.102502
# channel_num                                   0.063683                0.008826
# price_lifestage_segment_channel_num           0.217776                0.232538
# price_lifestage_segment_channel               0.217776                0.232538
# state_lifestage                               0.234456                0.246706
# promotional_price_lifestage_segment           0.950556                0.557450
# state_promotional                             1.000000                0.636618
# log_total_sale_value_x                        0.636618                1.000000
#
# [30 rows x 30 columns]

# %%
# predictor variables that can be used in OLS without causing multicollinearity
# promotional_total_sals_value/total_sale_value, customer/transaction count 
# !! It's better to obtain information about the relevant socialeconomic index if we want to include customer segment variable in our modles 



import statsmodels.api as sm

X = sales_train1[['total_promotional_sales_value_x','customer_count','media_amount_spend','store_longitude','store_latitude','year_month_sales','price_lifestage_segment_channel_num','promotional_price_lifestage_segment','transaction_count', 'state_num','distance_kmart', 'distance_target', 'co']]
# price_lifestage_segment_channel_num'

scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

X = sm.add_constant(scaled_X)

# Fit the OLS regression model
model = sm.OLS(sales_train1['total_sale_value_x'], X).fit()

# Get a summary of the regression results
summary = model.summary()

summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     total_sale_value_x   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                 2.086e+06
# Date:                Fri, 06 Oct 2023   Prob (F-statistic):               0.00
# Time:                        21:22:30   Log-Likelihood:            -1.4471e+07
# No. Observations:             1814020   AIC:                         2.894e+07
# Df Residuals:                 1814006   BIC:                         2.894e+07
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1684.8965      0.523   3218.574      0.000    1683.870    1685.923
# x1          -200.9188      2.303    -87.258      0.000    -205.432    -196.406
# x2          -976.0369      4.189   -233.020      0.000    -984.246    -967.827
# x3            14.5804      0.580     25.133      0.000      13.443      15.718
# x4             6.6480      0.592     11.238      0.000       5.489       7.807
# x5            25.2225      0.638     39.530      0.000      23.972      26.473
# x6           126.9796      0.529    240.154      0.000     125.943     128.016
# x7            36.5019      0.579     63.019      0.000      35.367      37.637
# x8           755.5801      2.086    362.203      0.000     751.491     759.669
# x9          3208.6861      4.525    709.156      0.000    3199.818    3217.554
# x10           34.0780      0.708     48.165      0.000      32.691      35.465
# x11           22.6767      0.597     38.008      0.000      21.507      23.846
# x12           15.9291      0.595     26.775      0.000      14.763      17.095
# x13           37.2171      0.544     68.455      0.000      36.151      38.283
# ==============================================================================
# Omnibus:                  1214150.479   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        958909258.531
# Skew:                           1.860   Prob(JB):                         0.00
# Kurtosis:                     115.574   Cond. No.                         22.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sales_train1['log_total_sale_value_x'] = np.log(sales_train1['total_sale_value_x'] + 1)

sales_test1['log_total_sale_value_x'] = np.log(sales_test1['total_sale_value_x'] + 1)

# %%
# predictor variables that can be used in OLS without causing multicollinearity
# promotional_total_sals_value/total_sale_value, customer/transaction count 
# !! It's better to obtain information about the relevant socialeconomic index if we want to include customer segment variable in our modles 

#OLS_log

import statsmodels.api as sm

X = sales_train1[['total_promotional_sales_value_x','customer_count','media_amount_spend','store_longitude','store_latitude','year_month_sales','price_lifestage_segment_channel_num','promotional_price_lifestage_segment','transaction_count', 'state_num','distance_kmart', 'distance_target', 'co']]
# price_lifestage_segment_channel_num'

scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

X = sm.add_constant(scaled_X)

# Fit the OLS regression model
model_log = sm.OLS(sales_train1['log_total_sale_value_x'], X).fit()

# Get a summary of the regression results
summary = model_log.summary()

summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     log_total_sale_value_x   R-squared:                       0.631
# Model:                                OLS   Adj. R-squared:                  0.631
# Method:                     Least Squares   F-statistic:                 2.386e+05
# Date:                    Fri, 06 Oct 2023   Prob (F-statistic):               0.00
# Time:                            22:51:50   Log-Likelihood:            -1.6159e+06
# No. Observations:                 1814020   AIC:                         3.232e+06
# Df Residuals:                     1814006   BIC:                         3.232e+06
# Df Model:                              13
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.8643      0.000   1.57e+04      0.000       6.863       6.865
# x1             0.7272      0.002    377.626      0.000       0.723       0.731
# x2             0.6721      0.004    191.866      0.000       0.665       0.679
# x3             0.0102      0.000     21.008      0.000       0.009       0.011
# x4            -0.0137      0.000    -27.742      0.000      -0.015      -0.013
# x5             0.0121      0.001     22.610      0.000       0.011       0.013
# x6             0.0752      0.000    170.050      0.000       0.074       0.076
# x7             0.1867      0.000    385.335      0.000       0.186       0.188
# x8            -0.6547      0.002   -375.246      0.000      -0.658      -0.651
# x9            -0.0884      0.004    -23.353      0.000      -0.096      -0.081
# x10            0.0410      0.001     69.213      0.000       0.040       0.042
# x11            0.0566      0.000    113.448      0.000       0.056       0.058
# x12            0.0151      0.000     30.348      0.000       0.014       0.016
# x13            0.0290      0.000     63.739      0.000       0.028       0.030
# ==============================================================================
# Omnibus:                   535268.231   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8280228.049
# Skew:                          -1.004   Prob(JB):                         0.00
# Kurtosis:                      13.272   Cond. No.                         22.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Lasso regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as mse


X_train = sales_train1[['total_promotional_sales_value_x','customer_count','media_amount_spend','store_longitude','store_latitude','year_month_sales','price_lifestage_segment_channel_num','promotional_price_lifestage_segment','transaction_count', 'state_num','distance_kmart', 'distance_target', 'co']].to_numpy()
y_train = sales_train1['total_sale_value_x'].to_numpy()

X_test = sales_test1[['total_promotional_sales_value_x','customer_count','media_amount_spend','store_longitude','store_latitude','year_month_sales','price_lifestage_segment_channel_num','promotional_price_lifestage_segment','transaction_count', 'state_num','distance_kmart', 'distance_target', 'co']].to_numpy()
y_test = sales_test1['total_sale_value_x'].to_numpy()

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

alphas = np.linspace(0, 50000, 100)

neg_mse = []
for alpha in alphas:
    model = Lasso(alpha = alpha)
    scores_mse = cross_val_score(model, X_train, y_train, cv = 5, scoring = 'neg_mean_squared_error')
    neg_mse.append(scores_mse.mean())
    
plt.figure()
plt.plot(alphas, neg_mse)
plt.title('Hyperparameter Sweep')
plt.xlabel(r'$\alpha$')
plt.ylabel('Negative MSE')
plt.tight_layout()
plt.savefig('plot.png', dpi = 200)

best_alpha = alphas[np.argmax(neg_mse)]

final_model = Lasso(alpha = best_alpha)
final_model.fit(X_train, y_train)

y_pred = final_model.predict(X_test)

print('Alpha: {:.2f}'.format(best_alpha))
print('RMSE: {:.2f}'.format(mse(y_test, y_pred, squared = False)))
# Out:
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.608e+11, tolerance: 1.154e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.608e+11, tolerance: 1.154e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.597e+11, tolerance: 1.145e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.595e+11, tolerance: 1.149e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.627e+11, tolerance: 1.150e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /var/folders/sm/pvsh_08j0q9fp5m216cy4qhw0000gn/T/ipykernel_12452/1174428574.py:41: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   final_model.fit(X_train, y_train)
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/pan./PycharmProjects/James/venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.509e+11, tolerance: 1.438e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# Alpha: 0.00
# RMSE: 696.18

# %%
# 获取特征的系数
coefficients = final_model.coef_

# 将系数与其相应的特征名配对并打印结果
for feature, coef in zip(features, coefficients):
    print(f'{feature}: {coef:.2f}')
# Out:
# total_promotional_sales_value_x: -200.92
# customer_count: -976.04
# media_amount_spend: 14.58
# store_longitude: 6.65
# store_latitude: 25.22
# year_month_sales: 126.98
# price_lifestage_segment_channel_num: 36.50
# promotional_price_lifestage_segment: 755.58
# transaction_count: 3208.69
# state_num: 34.08
# distance_kmart: 22.68
# distance_target: 15.93
# co: 37.22

# %%
# #year_month_sales: 130.77

# 每增加一个单位的 year_month_sales，销售额的预期将增加 130.77 个单位。
# price_lifestage_segment_channel_num: 46.55

# 每增加一个单位的 price_lifestage_segment_channel_num，销售额的预期将增加 46.55 个单位。
# promotional_price_lifestage_segment: 681.92

# 此系数的正值表明，与预期不符，promotional_price_lifestage_segment 的增加与销售额的增加正相关。每增加一个单位的 promotional_price_lifestage_segment，销售额的预期将增加 681.92 个单位。
# transaction_count: 2126.37

# transaction_count 似乎是最重要的特征，每增加一个单位的 transaction_count，销售额的预期将增加 2126.37 个单位。
# state_num: 53.47

# state_num 每增加一个单位，销售额的预期将增加 53.47 个单位。
# distance_kmart: 35.03

# distance_kmart 每增加一个单位，销售额的预期将增加 35.03 个单位。
# distance_target: 17.44

# distance_target 每增加一个单位，销售额的预期将增加 17.44 个单位。
# co: 41.39

# co 每增加一个单位，销售额的预期将增加 41.39 个单位。
# 这些系数提供了对每个特征如何影响目标变量（销售额）的洞见。如前所述，请确保在制定策略或做出决策时验证这些发现，并考虑所有可能的业务背景和外部因素。希望这些解释有助于您理解模型的输出！

# %% [markdown]
# ### Lasso (Log)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as mse

features = ['year_month_sales','price_lifestage_segment_channel_num','promotional_price_lifestage_segment','transaction_count', 'state_num','distance_kmart', 'distance_target', 'co']

X_train = sales_train1[features].to_numpy()
y_train = sales_train1['log_total_sale_value_x'].to_numpy()

X_test = sales_test1[features].to_numpy()
y_test = sales_test1['log_total_sale_value_x'].to_numpy()

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

alphas = np.linspace(0, 50000, 100)

neg_mse = []
for alpha in alphas:
    model = Lasso(alpha = alpha)
    scores_mse = cross_val_score(model, X_train, y_train, cv = 5, scoring = 'neg_mean_squared_error')
    neg_mse.append(scores_mse.mean())
    
plt.figure()
plt.plot(alphas, neg_mse)
plt.title('Hyperparameter Sweep')
plt.xlabel(r'$\alpha$')
plt.ylabel('Negative MSE')
plt.tight_layout()
plt.savefig('plot.png', dpi = 200)

best_alpha = alphas[np.argmax(neg_mse)]

final_model = Lasso(alpha = best_alpha)
final_model.fit(X_train, y_train)

y_pred = final_model.predict(X_test)

print('Alpha: {:.2f}'.format(best_alpha))
print('RMSE: {:.2f}'.format(mse(y_test, y_pred, squared = False)))
# Out:
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.788e+05, tolerance: 1.369e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.790e+05, tolerance: 1.367e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.789e+05, tolerance: 1.368e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.789e+05, tolerance: 1.367e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.786e+05, tolerance: 1.366e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /var/folders/8w/rtkgb3fs68q5hlyzf898d6zm0000gn/T/ipykernel_53847/3126207297.py:42: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   final_model.fit(X_train, y_train)
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/tcrontsui/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.486e+05, tolerance: 1.709e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# Alpha: 0.00
# RMSE: 0.62

# %%
# 获取特征的系数
coefficients = final_model.coef_

# 将系数与其相应的特征名配对并打印结果
for feature, coef in zip(features, coefficients):
    print(f'{feature}: {coef:.2f}')
# Out:
# year_month_sales: 0.07
# price_lifestage_segment_channel_num: 0.14
# promotional_price_lifestage_segment: -0.14
# transaction_count: 0.80
# state_num: 0.05
# distance_kmart: 0.06
# distance_target: 0.01
# co: 0.03

# %% [markdown]
# ### Ridge

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

features = ['total_promotional_sales_value_x','customer_count','media_amount_spend','store_longitude','store_latitude','year_month_sales','price_lifestage_segment_channel_num','promotional_price_lifestage_segment','transaction_count', 'state_num','distance_kmart', 'distance_target', 'co']

X_train = sales_train1[features].to_numpy()
y_train = sales_train1['total_sale_value_x'].to_numpy()

X_test = sales_test1[features].to_numpy()
y_test = sales_test1['total_sale_value_x'].to_numpy()

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

neg_mse = []
alphas = np.logspace(-6, 6, 10)
for alpha in alphas:
    model = Ridge(alpha = alpha)
    scores_mse = cross_val_score(model, X_train, y_train, cv = 5, scoring = 'neg_mean_squared_error')
    neg_mse.append(scores_mse.mean())

plt.figure()
plt.plot(alphas, neg_mse)
plt.title('Hyperparameter Sweep')
plt.xlabel(r'$\alpha$')
plt.ylabel('Negative MSE')
plt.xscale('log')
plt.savefig('plot.png')

best_alpha = alphas[np.argmax(neg_mse)]

final_model = Ridge(alpha = best_alpha)
final_model.fit(X_train, y_train)

y_pred = final_model.predict(X_test)

print('Alpha: {:.2f}'.format(best_alpha))
print('RMSE: {:.2f}'.format(mse(y_test, y_pred, squared = False)))
# Out:
# Alpha: 0.00
# RMSE: 696.18

# %%
# 获取特征的系数
coefficients = final_model.coef_

# 将系数与其相应的特征名配对并打印结果
for feature, coef in zip(features, coefficients):
    print(f'{feature}: {coef:.2f}')
# Out:
# total_promotional_sales_value_x: -200.92
# customer_count: -976.04
# media_amount_spend: 14.58
# store_longitude: 6.65
# store_latitude: 25.22
# year_month_sales: 126.98
# price_lifestage_segment_channel_num: 36.50
# promotional_price_lifestage_segment: 755.58
# transaction_count: 3208.69
# state_num: 34.08
# distance_kmart: 22.68
# distance_target: 15.93
# co: 37.22

# %% [markdown]
# ### Ridge (log)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

features = ['year_month_sales','price_lifestage_segment_channel_num','promotional_price_lifestage_segment','transaction_count', 'state_num','distance_kmart', 'distance_target', 'co']

X_train = sales_train1[features].to_numpy()
y_train = sales_train1['log_total_sale_value_x'].to_numpy()

X_test = sales_test1[features].to_numpy()
y_test = sales_test1['log_total_sale_value_x'].to_numpy()

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

neg_mse = []
alphas = np.logspace(-6, 6, 100)
for alpha in alphas:
    model = Ridge(alpha = alpha)
    scores_mse = cross_val_score(model, X_train, y_train, cv = 5, scoring = 'neg_mean_squared_error')
    neg_mse.append(scores_mse.mean())

plt.figure()
plt.plot(alphas, neg_mse)
plt.title('Hyperparameter Sweep')
plt.xlabel(r'$\alpha$')
plt.ylabel('Negative MSE')
plt.xscale('log')
plt.savefig('plot.png')

best_alpha = alphas[np.argmax(neg_mse)]

final_model = Ridge(alpha = best_alpha)
final_model.fit(X_train, y_train)

y_pred = final_model.predict(X_test)

print('Alpha: {:.2f}'.format(best_alpha))
print('RMSE: {:.2f}'.format(mse(y_test, y_pred, squared = False)))
# Out:
# Alpha: 100.00
# RMSE: 0.62

# %%
# 获取特征的系数
coefficients = final_model.coef_

# 将系数与其相应的特征名配对并打印结果
for feature, coef in zip(features, coefficients):
    print(f'{feature}: {coef:.2f}')
# Out:
# year_month_sales: 0.07
# price_lifestage_segment_channel_num: 0.14
# promotional_price_lifestage_segment: -0.14
# transaction_count: 0.80
# state_num: 0.05
# distance_kmart: 0.06
# distance_target: 0.01
# co: 0.03

# %%
# year_month_sales: 0.07

# 这表示year_month_sales与log_total_sale_value_x正相关。当year_month_sales增加1单位时，预计log_total_sale_value_x将增加0.07。等价于说，当year_month_sales增加1单位时，total_sale_value_x将增加大约7%。
# price_lifestage_segment_channel_num: 0.14

# 这个变量也是正相关的，并且影响比year_month_sales要大一些。具体来说，price_lifestage_segment_channel_num增加1单位时，total_sale_value_x预计将增加15%。
# promotional_price_lifestage_segment: -0.14

# 此变量与log_total_sale_value_x负相关。当promotional_price_lifestage_segment增加1单位时，total_sale_value_x预计将减少约13%。
# transaction_count: 0.80

# 这个变量的系数最大，表示它对模型的影响相当显著。当transaction_count增加1单位时，total_sale_value_x预计将增加大约122%。
# state_num: 0.05

# state_num的影响较小但仍然正相关。state_num增加1单位时，total_sale_value_x预计将增加大约5%。
# distance_kmart: 0.06

# 类似地，distance_kmart与log_total_sale_value_x正相关。其增加1单位时，total_sale_value_x预计将增加约6%。
# distance_target: 0.01

# 这个变量的系数最小，暗示它对模型的影响最小。distance_target增加1单位时，total_sale_value_x仅预计将增加约1%。
# co: 0.03

# co的影响也相对较小，增加1单位时，total_sale_value_x预计将增加约3%。
# 总之，transaction_count对模型的影响最大，其次是promotional_price_lifestage_segment（尽管它有一个负的系数）。distance_target和co的影响相对较小。

# %%
pd.set_option('display.max_columns', None)

sales_train1.head(
)

# pd.reset_option('display.max_columns')
# Out:
#                            store_id sales_channel customer_state  \
# 0  536fcc1021bff60edb212ca9b2480757         Store            NSW
# 1  151e50feaf21b61cf23e0b944abebe28         Store            VIC
# 2  b94d71e6bc4cc21ffbaaef5e4aca6f03         Store            QLD
# 3  336e7e53cf0e3fbc9eb41bfaf6dc4847         Store             SA
# 4  97012ce84c33e28732cb5f12bb92363c         Store            VIC
#
#    customer_postcode           price_lifestage_segment  customer_count  \
# 0             2550.0               Budget-New Families              51
# 1             3222.0                   Budget-Retirees               8
# 2             4101.0  Mainstream-Young Singles/Couples              10
# 3             5253.0         Mainstream-Young Families              79
# 4             3064.0              Premium-New Families              58
#
#    transaction_count  total_sale_value_x  total_sale_value_ex_gst_x  \
# 0                 77             6691.29                    6146.98
# 1                  8              364.53                     331.40
# 2                 11              446.25                     405.69
# 3                119             7479.89                    6817.90
# 4                 84             6172.44                    5630.27
#
#    total_promotional_sales_value_x financial_week_end_date store_state  \
# 0                          1545.78              2023-03-26         NSW
# 1                            89.72              2022-01-02         VIC
# 2                             9.75              2023-03-19         QLD
# 3                          1365.50              2023-01-29          SA
# 4                           508.59              2021-11-07         VIC
#
#    store_postcode  store_latitude  store_longitude  co_location_flag  \
# 0            2550        -36.6785         149.8398              True
# 1            3220        -38.1467         144.3587              True
# 2            4122        -27.5600         153.0811              True
# 3            5253        -35.1183         139.2747              True
# 4            3064        -37.5939         144.9103              True
#
#   distance_to_kmart distance_to_target  total_sale_value_y  \
# 0             >5 KM              >5 KM         38132622.27
# 1            1-3 KM        Same Centre         57694483.90
# 2       Same Centre        Same Centre         92482637.90
# 3             >5 KM              >5 KM         42636413.34
# 4       Same Centre              >5 KM         54545504.41
#
#    total_promotional_sales_value_y  total_sale_value_ex_gst_y year_month  \
# 0                       5879501.90                34759019.81    2023-03
# 1                       7166089.98                52597105.02    2022-01
# 2                       9571752.04                84342899.73    2023-03
# 3                       6131102.71                38922466.04    2023-01
# 4                       7088165.04                49733005.77    2021-11
#
#    media_amount_spend                segment main_segment  distance_kmart  \
# 0         6180823.875           New Families       Budget            1.00
# 1         3209616.050               Retirees       Budget            0.87
# 2         2876333.925  Young Singles/Couples   Mainstream            0.66
# 3          356125.960         Young Families   Mainstream            1.00
# 4         1335517.270           New Families      Premium            0.66
#
#    distance_target  distance_kmart_target    co  price_lifestage_segment_num  \
# 0             0.94                 0.9400  0.68                         0.75
# 1             0.73                 0.6351  0.68                         0.43
# 2             0.73                 0.4818  0.68                         0.41
# 3             0.94                 0.9400  0.68                         0.73
# 4             0.94                 0.6204  0.68                         0.34
#
#    main_segment_num  segment_num  state_num  channel_num  \
# 0              1.00         0.72       1.00          1.0
# 1              1.00         0.57       0.75          1.0
# 2              0.81         0.52       0.98          1.0
# 3              0.81         1.00       0.71          1.0
# 4              0.56         0.72       0.75          1.0
#
#    price_lifestage_segment_channel_num  price_lifestage_segment_channel  \
# 0                                 0.75                             0.75
# 1                                 0.43                             0.43
# 2                                 0.41                             0.41
# 3                                 0.73                             0.73
# 4                                 0.34                             0.34
#
#    state_lifestage  promotional_price_lifestage_segment  state_promotional
# 0           0.7500                            1159.3350          1545.7800
# 1           0.3225                              38.5796            67.2900
# 2           0.4018                               3.9975             9.5550
# 3           0.5183                             996.8150           969.5050
# 4           0.2550                             172.9206           381.4425

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# ### Group by each categorical variable and use proportion of mean total sales value to turn categorical variables to numerical

# %%
sales_train1.groupby(['main_segment'])['total_sale_value_x'].mean()
# Out:
# main_segment
# Budget        2062.263988
# Mainstream    1668.855332
# Premium       1149.223072
# Name: total_sale_value_x, dtype: float64

# %%
sales_train1.groupby(['customer_state'])['total_sale_value_x'].mean()
# Out:
# customer_state
# ACT    1106.425216
# NSW    1905.273026
# NT     1641.390572
# QLD    1835.511444
# SA     1351.142865
# TAS    1484.289173
# VIC    1421.938253
# WA     1623.004088
# Name: total_sale_value_x, dtype: float64

# %%
sales_train1.groupby(['price_lifestage_segment'])['total_sale_value_x'].mean() / 3036.72
# Out:
# price_lifestage_segment
# Budget-Midage Singles/Couples        0.439158
# Budget-New Families                  0.747243
# Budget-Older Families                0.617496
# Budget-Older Singles/Couples         0.622212
# Budget-Retirees                      0.432978
# Budget-Young Families                1.000000
# Budget-Young Singles/Couples         0.517195
# Mainstream-Midage Singles/Couples    0.370202
# Mainstream-New Families              0.512663
# Mainstream-Older Families            0.479408
# Mainstream-Older Singles/Couples     0.630931
# Mainstream-Retirees                  0.530621
# Mainstream-Young Families            0.731999
# Mainstream-Young Singles/Couples     0.410341
# Premium-Midage Singles/Couples       0.269670
# Premium-New Families                 0.341299
# Premium-Older Families               0.303588
# Premium-Older Singles/Couples        0.433644
# Premium-Retirees                     0.382659
# Premium-Young Families               0.505396
# Premium-Young Singles/Couples        0.250778
# Name: total_sale_value_x, dtype: float64

# %%
sales_train1.groupby(['distance_to_target'])['total_sale_value_x'].mean()
# Out:
# distance_to_target
# 1-3 KM         1884.439808
# 3-5 KM         1506.608861
# <1 KM          1957.985187
# >5 KM          1847.794114
# Same Centre    1432.693221
# Name: total_sale_value_x, dtype: float64

# %%
sales_train1.groupby(['co_location_flag'])['total_sale_value_x'].mean() /4043.492276
# Out:
# co_location_flag
# False    0.59381
# True     0.40619
# Name: total_sale_value_x, dtype: float64

# %%
1884.439808+1506.608861+1957.985187+1847.794114+1432.693221
# Out:
# 8629.521191

# %%
sales_train1.groupby(['price_lifestage_segment'])['total_promotional_sales_value_x'].mean()
# Out:
# price_lifestage_segment
# Budget-Midage Singles/Couples        237.182902
# Budget-New Families                  378.299630
# Budget-Older Families                348.501292
# Budget-Older Singles/Couples         369.060261
# Budget-Retirees                      238.036095
# Budget-Young Families                514.169683
# Budget-Young Singles/Couples         296.353009
# Mainstream-Midage Singles/Couples    156.835405
# Mainstream-New Families              203.074366
# Mainstream-Older Families            202.405025
# Mainstream-Older Singles/Couples     273.881555
# Mainstream-Retirees                  216.308903
# Mainstream-Young Families            283.849949
# Mainstream-Young Singles/Couples     175.207371
# Premium-Midage Singles/Couples       109.565409
# Premium-New Families                 125.694982
# Premium-Older Families               119.749583
# Premium-Older Singles/Couples        177.190857
# Premium-Retirees                     145.986552
# Premium-Young Families               183.253268
# Premium-Young Singles/Couples        101.189760
# Name: total_promotional_sales_value_x, dtype: float64

# %%
sales_train1.groupby(['sales_channel'])['total_sale_value_x'].mean() /1694.856398
